# %% [markdown]
# # PyMetaMapLite Example

# %%
from collections import namedtuple
import nltk
from nltk.tokenize import TreebankWordTokenizer
from metamaplite import MetaMapLite

# %%
def loadtextfile(inputfile):
    """ Load textfile and return as string """
    text = ''
    with open(inputfile) as fp:
        text = fp.read()
    return text

# %% [markdown]
# Load input text:

# %%
inputfilename = 'neonatal2.txt'
inputtext = loadtextfile(inputfilename)

# %% [markdown]
# Location of MetaMapLite UMLS indexes:

# %%
ivfdir = '/path/to/public_mm_lite/data/ivf/2020AA/USAbase'

# %% [markdown]
# Assign allowed vocabulary source list, semantic type list, stopwords, and term excluded by concept unique identifer.

# %%
use_sources = []
use_semtypes = []
stopwords = []
excludedterms = []

# %% [markdown]
# The token's part-of-speech must be in postags set to be looked up in dictionary.

# %%
postags = set(["CD", "FW", "RB", "IN", "NN", "NNS",
               "NNP", "NNPS", "JJ", "JJR", "JJS", "LS"])

# %% [markdown]
# Instantiate a MetaMapLite instance.

# %%
mminst = MetaMapLite(ivfdir, use_sources, use_semtypes, postags,
                     stopwords, excludedterms)

# %% [markdown]
# Named tuple ``Token`` contains token text in ``text``, part of speech tag  in ``tag_``, and charater offset is in ``idx``.

# %%
Token = namedtuple('Token', ['text', 'tag_', 'idx'])

# %%
inputtext
# Out:
# "The 24-h period of exposure to chemically defined medium was not\nsufficient to reverse the effects imposed on the cells by the serum\nused in the first phase of growth. Effect of change in growth\nenvironment on cultured myocardial cells investigated in a\nstandardized medium. Neonatal rat heart cells cultivated in either of\ntwo different media which varied only in their serum supplements were\ntransferred to chemically defined medium (Ham's F10) for 24 h before\nmeasuring a variety of parameters. The 24-h period of exposure to\nchemically defined medium was not sufficient to reverse the effects\nimposed on the cells by the serum used in the first phase of\ngrowth. The cells differed in rate and duration of action potentials\nand contractions. The initial serum composition affected the response\nof the cells to calcium deficiency. Studies involving the effects of\npharmaceutical reagents such as isoproterenol were also influenced by\nthe serum. In attempting to determine the cause and possible\nmechanism, it was found that mitochondrial membrane permeability for\nnitroblue tetrazolium was unchanged. Although the serum supplements\ndiffered in fatty acid composition, the fatty acid profiles of the\ncell phospholipids were relatively constant. We conclude that the\nfunction of the cells is affected by the growth environment,\nparticularly serum; that a short exposure to a uniform chemically\ndefined medium is not sufficient to reverse these effects; and that\nthe differences in effects are not the result of changes in the fatty\nacid composition of the whole cell phospholipids nor in mitochondrial\nmembrane permeability as measured by nitroblue tetrazolium.\n"

# %% [markdown]
# Convert text into sentences, tokenize each sentence, and apply part-of-speech tagger to each list of sentence tokens.  Then apply recognizer to tagged tokenlist.

# %%
sentlist = nltk.sent_tokenize(inputtext)
sent_resultlist = []
sentidx = 0
for sentence in sentlist:
    spanlist = list(TreebankWordTokenizer().span_tokenize(sentence))
    texttokenlist = [sentence[start:end] for start, end in spanlist]
    
    postokenlist = nltk.pos_tag(texttokenlist)
    tokenlist = []
    for token, span in zip(postokenlist, spanlist):
        tokenlist.append(Token(text=token[0], tag_=token[1],
                               idx=(sentidx+span[0])))
    matches = mminst.get_entities(tokenlist, span_info=True)
    sent_resultlist.append(((sentence, sentidx), matches))
    sentidx = sentidx + len(sentence) + 1

# %%
len(sentlist), len(sent_resultlist)
# Out:
# (10, 10)

# %%
def display_results(sent_resultlist):
    """ process inputtext returning list of matches """
    for sentence, matches in sent_resultlist:
        print('sentence: "%s, %d"' % sentence)
        for term in matches:
            print('  "%s"' % term.text)
            print('    start: %d' % term.start)
            print('    end: %d' % term.end)
            print('    postings:')
            for post in term.postings:
                print('      %s' % post)

# %%
display_results(sent_resultlist)
# Out:
# sentence: "The 24-h period of exposure to chemically defined medium was not
# sufficient to reverse the effects imposed on the cells by the serum
# used in the first phase of growth., 0"
#   "period"
#     start: 9
#     end: 15
#     postings:
#       C0025344|S1237140|33|period|CHV|PT
#       C0025344|S6137818|34|Period|MEDLINEPLUS|SY
#       C0439531|S1237140|2|period|CHV|PT
#       C1561960|S1237140|2|period|HL7V3.0|PT
#       C1948053|S6137818|2|Period|NCI|PT
#       C2347804|S6137818|3|Period|NCI|SY
#   "exposure to"
#     start: 19
#     end: 30
#     postings:
#       C0332157|S0642558|1|Exposure to|MTH|PN
#       C0332157|S11885829|2|exposure to|CHV|SY
#   "chemically"
#     start: 31
#     end: 41
#     postings:
#       C0220806|S7669275|24|Chemically|NCI|AD
#   "defined"
#     start: 42
#     end: 49
#     postings:
#       C1704788|S7670164|5|Defined|NCI|AD
#       C4724435|S7670164|3|Defined|NCI|SY
#   "medium"
#     start: 50
#     end: 56
#     postings:
#       C0009458|S0943869|11|Medium|NCI|SY
#       C0439536|S0943869|1|Medium|RCD|PT
#       C0439536|S0943869|2|Medium|NCI|PT
#       C0439536|S0943869|3|Medium|NCI|SY
#       C0439536|S0943869|4|Medium|LNC|LA
#       C0439536|S0943869|5|Medium|MTH|PN
#       C0439536|S11912821|6|medium|CHV|PT
#       C0439536|S6941619|7|MEDIUM|NCI_CDISC|PT
#       C1561547|S0943869|2|Medium|HL7V3.0|PT
#       C1705217|S0943869|2|Medium|NCI|PT
#       C3244283|S11912821|2|medium|HL7V3.0|PT
#       C4085196|S0943869|3|Medium|NCI|SY
#       C4522282|S0943869|3|Medium|NCI|SY
#       C4522283|S0943869|4|Medium|NCI|SY
#       C4722268|S0943869|3|Medium|NCI|SY
#   "not"
#     start: 61
#     end: 64
#     postings:
#       C1417836|S7299739|7|NOT|HGNC|SYN
#       C1417836|S7299739|8|NOT|OMIM|ACR
#       C1518422|S6136096|9|Not|NCI|AD
#       C1518422|S6136096|10|Not|NCI|SY
#       C1518422|S6136096|11|Not|NCI|SY
#       C1518422|S6136096|12|Not|LNC|LA
#       C1518422|S6136096|13|Not|NCI|SY
#   "sufficient"
#     start: 65
#     end: 75
#     postings:
#       C0205410|S0324836|1|Sufficient|NCI|PT
#       C0205410|S0324836|2|Sufficient|NCI|SY
#       C0205410|S0324836|3|Sufficient|LNC|LA
#       C0205410|S0324836|4|Sufficient|MTH|PN
#       C0205410|S11942554|5|sufficient|CHV|PT
#   "effects"
#     start: 91
#     end: 98
#     postings:
#       C1280500|S11882510|4|effects|CHV|SY
#       C1280500|S14453944|5|Effects|NCI|SY
#   "cells"
#     start: 114
#     end: 119
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "serum"
#     start: 127
#     end: 132
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "first"
#     start: 145
#     end: 150
#     postings:
#       C0205435|S11889009|2|first|CHV|PT
#       C0205435|S0324862|3|First|RCD|PT
#       C1279901|S0324862|3|First|NCI|SY
#       C1279901|S0324862|4|First|NCI|SY
#       C1279901|S0324862|5|First|NCI|PT
#   "phase"
#     start: 151
#     end: 156
#     postings:
#       C0205390|S0324816|1|Phase|RCD|AT
#       C0205390|S0324816|2|Phase|NCI|PT
#       C0205390|S0324816|3|Phase|MTH|PN
#       C0205390|S1237339|4|phase|CHV|PT
#       C1710475|S1237339|4|phase|NCI_CDISC-GLOSS|PT
#   "growth"
#     start: 160
#     end: 166
#     postings:
#       C0018270|S0046170|1|Growth|LCH|PT
#       C0018270|S0046170|2|Growth|MSH|MH
#       C0018270|S0046170|3|Growth|NCI|SY
#       C0018270|S0046170|4|Growth|LCH_NW|PT
#       C0018270|S0046170|5|Growth|NANDA-I|HC
#       C0018270|S0046170|6|Growth|NOC|OC
#       C0018270|S0046170|7|Growth|NOC|ID
#       C0018270|S0046170|8|Growth|NOC|ID
#       C0018270|S0046170|9|Growth|NOC|ID
#       C0018270|S0046170|10|Growth|PSY|ET
#       C0018270|S0046170|11|Growth|MTH|PN
#       C0018270|S0419586|12|growth|CHV|SY
#       C0018270|S0419586|13|growth|GO|PT
#       C0018270|S0890927|14|GROWTH|OMIM|HT
#       C0220844|S0419586|2|growth|MSH|PXQ
#       C1457898|S0890927|2|GROWTH|MSH|QEV
#       C1621966|S0046170|3|Growth|NCI|SY
#       C2911660|S0046170|2|Growth|NCI|PT
# sentence: "Effect of change in growth
# environment on cultured myocardial cells investigated in a
# standardized medium., 168"
#   "Effect"
#     start: 168
#     end: 174
#     postings:
#       C1280500|S0637364|1|Effect|NCI|PT
#       C1280500|S0637364|2|Effect|MTH|PN
#       C1280500|S11882511|3|effect|CHV|PT
#       C1518681|S11882511|4|effect|NCI_CDISC-GLOSS|PT
#       C2348382|S0637364|3|Effect|NCI|SY
#   "change in"
#     start: 178
#     end: 187
#     postings:
#       C0392747|S11866223|4|change in|CHV|SY
#       C0443172|S11866223|6|change in|CHV|SY
#   "growth"
#     start: 188
#     end: 194
#     postings:
#       C0018270|S0046170|1|Growth|LCH|PT
#       C0018270|S0046170|2|Growth|MSH|MH
#       C0018270|S0046170|3|Growth|NCI|SY
#       C0018270|S0046170|4|Growth|LCH_NW|PT
#       C0018270|S0046170|5|Growth|NANDA-I|HC
#       C0018270|S0046170|6|Growth|NOC|OC
#       C0018270|S0046170|7|Growth|NOC|ID
#       C0018270|S0046170|8|Growth|NOC|ID
#       C0018270|S0046170|9|Growth|NOC|ID
#       C0018270|S0046170|10|Growth|PSY|ET
#       C0018270|S0046170|11|Growth|MTH|PN
#       C0018270|S0419586|12|growth|CHV|SY
#       C0018270|S0419586|13|growth|GO|PT
#       C0018270|S0890927|14|GROWTH|OMIM|HT
#       C0220844|S0419586|2|growth|MSH|PXQ
#       C1457898|S0890927|2|GROWTH|MSH|QEV
#       C1621966|S0046170|3|Growth|NCI|SY
#       C2911660|S0046170|2|Growth|NCI|PT
#   "environment"
#     start: 195
#     end: 206
#     postings:
#       C0014406|S0038087|1|Environment|MSH|MH
#       C0014406|S0038087|2|Environment|LNC|LPN
#       C0014406|S0038087|3|Environment|LNC|CN
#       C0014406|S0038087|4|Environment|MEDCIN|PT
#       C0014406|S0038087|5|Environment|PSY|PT
#       C0014406|S0038087|6|Environment|NCI|PT
#       C0014406|S0038087|7|Environment|MTH|PN
#       C0014406|S0418349|8|environment|AOD|DE
#       C0014406|S0418349|9|environment|CSP|PT
#       C0014406|S0418349|10|environment|OMS|TG
#       C0014406|S0418349|11|environment|CHV|PT
#   "myocardial"
#     start: 219
#     end: 229
#     postings:
#       C1522564|S0388775|1|Myocardial|NCI|PT
#       C1522564|S0388775|2|Myocardial|MTH|PN
#   "cells"
#     start: 230
#     end: 235
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "medium"
#     start: 267
#     end: 273
#     postings:
#       C0009458|S0943869|11|Medium|NCI|SY
#       C0439536|S0943869|1|Medium|RCD|PT
#       C0439536|S0943869|2|Medium|NCI|PT
#       C0439536|S0943869|3|Medium|NCI|SY
#       C0439536|S0943869|4|Medium|LNC|LA
#       C0439536|S0943869|5|Medium|MTH|PN
#       C0439536|S11912821|6|medium|CHV|PT
#       C0439536|S6941619|7|MEDIUM|NCI_CDISC|PT
#       C1561547|S0943869|2|Medium|HL7V3.0|PT
#       C1705217|S0943869|2|Medium|NCI|PT
#       C3244283|S11912821|2|medium|HL7V3.0|PT
#       C4085196|S0943869|3|Medium|NCI|SY
#       C4522282|S0943869|3|Medium|NCI|SY
#       C4522283|S0943869|4|Medium|NCI|SY
#       C4722268|S0943869|3|Medium|NCI|SY
# sentence: "Neonatal rat heart cells cultivated in either of
# two different media which varied only in their serum supplements were
# transferred to chemically defined medium (Ham's F10) for 24 h before
# measuring a variety of parameters., 275"
#   "Neonatal"
#     start: 275
#     end: 283
#     postings:
#       C0021289|S0694910|38|Neonatal|NCI|AD
#       C2939425|S11917591|4|neonatal|CHV|PT
#       C2939425|S0694910|5|Neonatal|RCD|PT
#   "rat heart"
#     start: 284
#     end: 293
#     postings:
#       C1882687|S7660100|1|Rat Heart|NCI|PT
#   "two"
#     start: 324
#     end: 327
#     postings:
#       C0205448|S0324875|1|Two|NCI|PT
#       C0205448|S0324875|2|Two|LNC|LPN
#       C0205448|S0324875|3|Two|NCI|SY
#       C0205448|S0324875|4|Two|NCI|SY
#       C0205448|S0324875|5|Two|LNC|LA
#       C0205448|S0324875|6|Two|MTH|PN
#   "different"
#     start: 328
#     end: 337
#     postings:
#       C1705242|S6936116|1|Different|NCI|AD
#       C1705242|S6936116|2|Different|MTH|PN
#   "media"
#     start: 338
#     end: 343
#     postings:
#       C0009458|S0387102|10|Media|NCI|PT
#       C0677540|S0387102|2|Media|RCD|PT
#       C1254021|S0387102|3|Media|UWDA|PT
#       C1254021|S11912481|4|media|CHV|PT
#   "only"
#     start: 357
#     end: 361
#     postings:
#       C0205171|S6991592|13|Only|NCI|SY
#   "serum"
#     start: 371
#     end: 376
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "supplements"
#     start: 377
#     end: 388
#     postings:
#       C0242295|S6142845|41|Supplements|NCI_CPTAC|PT
#   "chemically"
#     start: 409
#     end: 419
#     postings:
#       C0220806|S7669275|24|Chemically|NCI|AD
#   "defined"
#     start: 420
#     end: 427
#     postings:
#       C1704788|S7670164|5|Defined|NCI|AD
#       C4724435|S7670164|3|Defined|NCI|SY
#   "medium"
#     start: 428
#     end: 434
#     postings:
#       C0009458|S0943869|11|Medium|NCI|SY
#       C0439536|S0943869|1|Medium|RCD|PT
#       C0439536|S0943869|2|Medium|NCI|PT
#       C0439536|S0943869|3|Medium|NCI|SY
#       C0439536|S0943869|4|Medium|LNC|LA
#       C0439536|S0943869|5|Medium|MTH|PN
#       C0439536|S11912821|6|medium|CHV|PT
#       C0439536|S6941619|7|MEDIUM|NCI_CDISC|PT
#       C1561547|S0943869|2|Medium|HL7V3.0|PT
#       C1705217|S0943869|2|Medium|NCI|PT
#       C3244283|S11912821|2|medium|HL7V3.0|PT
#       C4085196|S0943869|3|Medium|NCI|SY
#       C4522282|S0943869|3|Medium|NCI|SY
#       C4522283|S0943869|4|Medium|NCI|SY
#       C4722268|S0943869|3|Medium|NCI|SY
#   "Ham"
#     start: 436
#     end: 439
#     postings:
#       C0030481|S1640469|54|HAM|MDR|OL
#       C0030481|S1640469|55|HAM|OMIM|ACR
#       C0279477|S1640469|6|HAM|PDQ|AB
#       C0279477|S1640469|7|HAM|NCI|AB
#       C1570167|S14774169|8|hAM|NCI|SY
#       C3853311|S7441753|1|Ham|LNC|LPN
#       C3853311|S7441753|2|Ham|MTH|PN
#   "F10"
#     start: 442
#     end: 445
#     postings:
#       C1414497|S7502946|7|F10|NCI|SY
#       C1414497|S7502946|8|F10|HGNC|ACR
#       C1414497|S7502946|9|F10|NCI_NCI-HGNC|PT
#       C1414497|S7502946|10|F10|OMIM|ACR
#   "for"
#     start: 447
#     end: 450
#     postings:
#       C0521125|S0887174|2|For|NCI|PT
#       C1421525|S6926717|4|FOR|HGNC|SYN
#       C1421525|S6926717|5|FOR|OMIM|ACR
#       C1562169|S6926717|3|FOR|AOT|ET
#       C4321252|S6926717|3|FOR|NCI|SY
#   "before"
#     start: 456
#     end: 462
#     postings:
#       C0332152|S0597822|1|Before|RCD|AT
#       C0332152|S0597822|2|Before|NCI|SY
#       C0332152|S0597822|3|Before|MTH|PN
#       C0332152|S11855275|4|before|CHV|PT
#       C0332152|S6931593|5|BEFORE|NCI_CDISC|PT
#   "variety"
#     start: 475
#     end: 482
#     postings:
#       C1883525|S7662720|3|Variety|NCI|PT
#       C2346866|S7662720|3|Variety|NCI|SY
#   "parameters"
#     start: 486
#     end: 496
#     postings:
#       C0449381|S0983567|3|Parameters|RCD|PT
# sentence: "The 24-h period of exposure to
# chemically defined medium was not sufficient to reverse the effects
# imposed on the cells by the serum used in the first phase of
# growth., 498"
#   "period"
#     start: 507
#     end: 513
#     postings:
#       C0025344|S1237140|33|period|CHV|PT
#       C0025344|S6137818|34|Period|MEDLINEPLUS|SY
#       C0439531|S1237140|2|period|CHV|PT
#       C1561960|S1237140|2|period|HL7V3.0|PT
#       C1948053|S6137818|2|Period|NCI|PT
#       C2347804|S6137818|3|Period|NCI|SY
#   "exposure to"
#     start: 517
#     end: 528
#     postings:
#       C0332157|S0642558|1|Exposure to|MTH|PN
#       C0332157|S11885829|2|exposure to|CHV|SY
#   "chemically"
#     start: 529
#     end: 539
#     postings:
#       C0220806|S7669275|24|Chemically|NCI|AD
#   "defined"
#     start: 540
#     end: 547
#     postings:
#       C1704788|S7670164|5|Defined|NCI|AD
#       C4724435|S7670164|3|Defined|NCI|SY
#   "medium"
#     start: 548
#     end: 554
#     postings:
#       C0009458|S0943869|11|Medium|NCI|SY
#       C0439536|S0943869|1|Medium|RCD|PT
#       C0439536|S0943869|2|Medium|NCI|PT
#       C0439536|S0943869|3|Medium|NCI|SY
#       C0439536|S0943869|4|Medium|LNC|LA
#       C0439536|S0943869|5|Medium|MTH|PN
#       C0439536|S11912821|6|medium|CHV|PT
#       C0439536|S6941619|7|MEDIUM|NCI_CDISC|PT
#       C1561547|S0943869|2|Medium|HL7V3.0|PT
#       C1705217|S0943869|2|Medium|NCI|PT
#       C3244283|S11912821|2|medium|HL7V3.0|PT
#       C4085196|S0943869|3|Medium|NCI|SY
#       C4522282|S0943869|3|Medium|NCI|SY
#       C4522283|S0943869|4|Medium|NCI|SY
#       C4722268|S0943869|3|Medium|NCI|SY
#   "not"
#     start: 559
#     end: 562
#     postings:
#       C1417836|S7299739|7|NOT|HGNC|SYN
#       C1417836|S7299739|8|NOT|OMIM|ACR
#       C1518422|S6136096|9|Not|NCI|AD
#       C1518422|S6136096|10|Not|NCI|SY
#       C1518422|S6136096|11|Not|NCI|SY
#       C1518422|S6136096|12|Not|LNC|LA
#       C1518422|S6136096|13|Not|NCI|SY
#   "sufficient"
#     start: 563
#     end: 573
#     postings:
#       C0205410|S0324836|1|Sufficient|NCI|PT
#       C0205410|S0324836|2|Sufficient|NCI|SY
#       C0205410|S0324836|3|Sufficient|LNC|LA
#       C0205410|S0324836|4|Sufficient|MTH|PN
#       C0205410|S11942554|5|sufficient|CHV|PT
#   "effects"
#     start: 589
#     end: 596
#     postings:
#       C1280500|S11882510|4|effects|CHV|SY
#       C1280500|S14453944|5|Effects|NCI|SY
#   "cells"
#     start: 612
#     end: 617
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "serum"
#     start: 625
#     end: 630
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "first"
#     start: 643
#     end: 648
#     postings:
#       C0205435|S11889009|2|first|CHV|PT
#       C0205435|S0324862|3|First|RCD|PT
#       C1279901|S0324862|3|First|NCI|SY
#       C1279901|S0324862|4|First|NCI|SY
#       C1279901|S0324862|5|First|NCI|PT
#   "phase"
#     start: 649
#     end: 654
#     postings:
#       C0205390|S0324816|1|Phase|RCD|AT
#       C0205390|S0324816|2|Phase|NCI|PT
#       C0205390|S0324816|3|Phase|MTH|PN
#       C0205390|S1237339|4|phase|CHV|PT
#       C1710475|S1237339|4|phase|NCI_CDISC-GLOSS|PT
#   "growth"
#     start: 658
#     end: 664
#     postings:
#       C0018270|S0046170|1|Growth|LCH|PT
#       C0018270|S0046170|2|Growth|MSH|MH
#       C0018270|S0046170|3|Growth|NCI|SY
#       C0018270|S0046170|4|Growth|LCH_NW|PT
#       C0018270|S0046170|5|Growth|NANDA-I|HC
#       C0018270|S0046170|6|Growth|NOC|OC
#       C0018270|S0046170|7|Growth|NOC|ID
#       C0018270|S0046170|8|Growth|NOC|ID
#       C0018270|S0046170|9|Growth|NOC|ID
#       C0018270|S0046170|10|Growth|PSY|ET
#       C0018270|S0046170|11|Growth|MTH|PN
#       C0018270|S0419586|12|growth|CHV|SY
#       C0018270|S0419586|13|growth|GO|PT
#       C0018270|S0890927|14|GROWTH|OMIM|HT
#       C0220844|S0419586|2|growth|MSH|PXQ
#       C1457898|S0890927|2|GROWTH|MSH|QEV
#       C1621966|S0046170|3|Growth|NCI|SY
#       C2911660|S0046170|2|Growth|NCI|PT
# sentence: "The cells differed in rate and duration of action potentials
# and contractions., 666"
#   "cells"
#     start: 670
#     end: 675
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "rate"
#     start: 688
#     end: 692
#     postings:
#       C0871208|S6139870|5|Rate|NCI|SY
#       C1521828|S6139870|1|Rate|LNC|CN
#       C1521828|S6139870|2|Rate|NCI|SY
#       C1521828|S6139870|3|Rate|NCI|PT
#       C1521828|S6139870|4|Rate|MTH|PN
#       C1549480|S6139870|2|Rate|HL7V2.5|PT
#   "duration"
#     start: 697
#     end: 705
#     postings:
#       C0449238|S0864336|2|Duration|RCD|AT
#       C0449238|S0864336|3|Duration|LNC|LPN
#       C0449238|S0864336|4|Duration|LNC|CN
#       C0449238|S0864336|5|Duration|NCI|SY
#       C0449238|S0864336|6|Duration|NCI_CPTAC|PT
#       C0449238|S0864336|7|Duration|NCI|PT
#       C0449238|S11881357|8|duration|CHV|PT
#       C0449238|S11881357|9|duration|NCI_BRIDG_3_0_3|PT
#       C0720099|S0864336|2|Duration|CHV|SY
#       C0720099|S0864336|3|Duration|MMSL|BN
#       C2926735|S0864336|1|Duration|RXNORM|BN
#       C2926735|S0864336|2|Duration|MTH|PN
#   "action potentials"
#     start: 709
#     end: 726
#     postings:
#       C0001272|S0010468|1|Action Potentials|MSH|MH
#       C0001272|S11844991|2|action potentials|CHV|SY
#   "contractions"
#     start: 731
#     end: 743
#     postings:
#       C0567116|S9059426|3|contractions|MEDCIN|SY
#       C1140999|S9059426|5|contractions|CHV|SY
# sentence: "The initial serum composition affected the response
# of the cells to calcium deficiency., 745"
#   "initial"
#     start: 749
#     end: 756
#     postings:
#       C0205265|S6325504|3|initial|CHV|PT
#       C0205265|S0324686|4|Initial|RCD|PT
#       C0205265|S0324686|5|Initial|LNC|LA
#       C0205265|S0324686|6|Initial|LNC|LPN
#       C1279901|S0324686|2|Initial|NCI|SY
#       C1555582|S0324686|4|Initial|NCI|SY
#       C1555582|S6325504|5|initial|HL7V3.0|PT
#       C1555582|S6325504|6|initial|HL7V3.0|PT
#       C1705684|S12203170|3|INITIAL|NCI_FDA|PT
#       C1705685|S12203170|3|INITIAL|NCI_FDA|PT
#   "serum"
#     start: 757
#     end: 762
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "composition"
#     start: 763
#     end: 774
#     postings:
#       C0486616|S1937865|1|Composition|NCI|PT
#       C0486616|S1937865|2|Composition|LNC|LPN
#       C0486616|S1937865|3|Composition|LCH|PT
#       C0486616|S1937865|4|Composition|LNC|CN
#       C0486616|S1937865|5|Composition|NCI_CDISC|SY
#       C0486616|S1937865|6|Composition|NCI_CDISC|PT
#       C0486616|S1937865|7|Composition|MTH|PN
#       C0486616|S6325206|8|composition|CHV|PT
#       C1555710|S6325206|2|composition|HL7V3.0|PT
#   "response"
#     start: 788
#     end: 796
#     postings:
#       C0871261|S6140517|2|Response|NCI|SY
#       C0871261|S6140517|3|Response|NCI|PT
#       C0871261|S6147280|4|response|CHV|SY
#       C1704632|S6140517|3|Response|NCI|SY
#       C1704632|S6147280|4|response|NCI_NCI-GLOSS|PT
#       C1706817|S6140517|2|Response|NCI|SY
#       C2911692|S6140517|3|Response|NCI|SY
#   "cells"
#     start: 804
#     end: 809
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "deficiency"
#     start: 821
#     end: 831
#     postings:
#       C0011155|S0628967|1|Deficiency|RCD|AT
#       C0011155|S0628967|2|Deficiency|NCI|PT
#       C0011155|S0628967|3|Deficiency|MTH|PN
#       C0011155|S0100832|4|deficiency|NCI_NCI-GLOSS|PT
#       C1623416|S0100832|2|deficiency|MSH|TQ
# sentence: "Studies involving the effects of
# pharmaceutical reagents such as isoproterenol were also influenced by
# the serum., 833"
#   "Studies"
#     start: 833
#     end: 840
#     postings:
#       C0947630|S11942206|8|studies|CHV|SY
#   "effects of"
#     start: 855
#     end: 865
#     postings:
#       C1704420|S4077569|1|effects of|ICPC2ICD10ENG|PT
#   "pharmaceutical"
#     start: 866
#     end: 880
#     postings:
#       C0013058|S6323368|12|Pharmaceutical|NCI_NCPDP|PT
#       C0013058|S6323368|13|Pharmaceutical|NCI|SY
#       C0031336|S6323368|9|Pharmaceutical|NCI|AD
#       C1135440|S11925827|2|pharmaceutical|CHV|PT
#       C1553890|S6323368|2|Pharmaceutical|HL7V3.0|PT
#   "reagents"
#     start: 881
#     end: 889
#     postings:
#       C0034760|S0080191|1|Reagents|UMD|RT
#       C0034760|S0080191|2|Reagents|MSH|PEP
#       C0034760|S11932217|3|reagents|CHV|SY
#   "isoproterenol"
#     start: 898
#     end: 911
#     postings:
#       C0022245|S0420902|1|isoproterenol|AOD|DE
#       C0022245|S0420902|2|isoproterenol|CSP|PT
#       C0022245|S0420902|3|isoproterenol|MMSL|GN
#       C0022245|S0420902|4|isoproterenol|CHV|PT
#       C0022245|S0420902|5|isoproterenol|NDDF|IN
#       C0022245|S0420902|6|isoproterenol|MTH|PN
#       C0022245|S0054663|7|Isoproterenol|LCH|PT
#       C0022245|S0054663|8|Isoproterenol|MSH|MH
#       C0022245|S0054663|9|Isoproterenol|NCI|PT
#       C0022245|S0054663|10|Isoproterenol|LCH_NW|PT
#       C0022245|S0054663|11|Isoproterenol|NCI_DCP|PT
#       C0022245|S0054663|12|Isoproterenol|MTHSPL|SU
#       C0022245|S0054663|13|Isoproterenol|DRUGBANK|SY
#       C0022245|S0054663|14|Isoproterenol|PSY|PT
#       C0022245|S0054663|15|Isoproterenol|RXNORM|IN
#       C0022245|S1711445|16|ISOPROTERENOL|NCI_FDA|PT
#       C0022245|S1711445|17|ISOPROTERENOL|VANDF|IN
#       C0022245|S1711445|18|ISOPROTERENOL|MTHSPL|SU
#   "serum"
#     start: 940
#     end: 945
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
# sentence: "In attempting to determine the cause and possible
# mechanism, it was found that mitochondrial membrane permeability for
# nitroblue tetrazolium was unchanged., 947"
#   "cause"
#     start: 978
#     end: 983
#     postings:
#       C0015127|S11864648|9|cause|CHV|PT
#       C1524003|S6933983|4|Cause|NCI|SY
#   "possible"
#     start: 988
#     end: 996
#     postings:
#       C0332149|S0716705|1|Possible|NCI|PT
#       C0332149|S0716705|2|Possible|NCI_FDA|PT
#       C0332149|S0716705|3|Possible|LNC|LA
#       C0332149|S0716705|4|Possible|MTH|PN
#       C0332149|S11928032|5|possible|CHV|PT
#       C1705910|S0716705|3|Possible|NCI|SY
#       C2362652|S0716705|2|Possible|RCD|PT
#   "mechanism"
#     start: 997
#     end: 1006
#     postings:
#       C0441712|S0942695|2|Mechanism|RCD|AT
#       C0441712|S0942695|3|Mechanism|NCI|PT
#       C0441712|S11912372|4|mechanism|CHV|PT
#       C1706376|S0942695|2|Mechanism|NCI_FDA|PT
#       C1706376|S0942695|3|Mechanism|NCI|SY
#   "mitochondrial membrane"
#     start: 1026
#     end: 1048
#     postings:
#       C0596952|S1234365|3|mitochondrial membrane|CSP|PT
#       C0596952|S1234365|4|mitochondrial membrane|GO|PT
#       C0596952|S3011716|5|Mitochondrial membrane|UWDA|SY
#       C0596952|S3011716|6|Mitochondrial membrane|FMA|SY
#       C0596952|S6133573|7|Mitochondrial Membrane|MSH|PM
#       C0596952|S6133573|8|Mitochondrial Membrane|NCI|PT
#   "for"
#     start: 1062
#     end: 1065
#     postings:
#       C0521125|S0887174|2|For|NCI|PT
#       C1421525|S6926717|4|FOR|HGNC|SYN
#       C1421525|S6926717|5|FOR|OMIM|ACR
#       C1562169|S6926717|3|FOR|AOT|ET
#       C4321252|S6926717|3|FOR|NCI|SY
#   "nitroblue tetrazolium"
#     start: 1066
#     end: 1087
#     postings:
#       C0028147|S0066863|1|Nitroblue Tetrazolium|MSH|MH
#       C0028147|S1235878|2|nitroblue tetrazolium|CHV|PT
#   "unchanged"
#     start: 1092
#     end: 1101
#     postings:
#       C0442739|S11949275|6|unchanged|CHV|PT
#       C0442739|S3605317|7|Unchanged|LNC|LA
#       C2346711|S3605317|4|Unchanged|NCI|SY
#       C2346711|S17856790|5|UNCHANGED|NCI_CDISC|PT
# sentence: "Although the serum supplements
# differed in fatty acid composition, the fatty acid profiles of the
# cell phospholipids were relatively constant., 1103"
#   "serum"
#     start: 1116
#     end: 1121
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "supplements"
#     start: 1122
#     end: 1133
#     postings:
#       C0242295|S6142845|41|Supplements|NCI_CPTAC|PT
#   "fatty acid"
#     start: 1146
#     end: 1156
#     postings:
#       C0015684|S0001341|13|Fatty acid|SNM|PT
#       C0015684|S0001341|14|Fatty acid|FMA|PT
#       C0015684|S0418706|15|fatty acid|CSP|PT
#       C0015684|S0418706|16|fatty acid|CHV|PT
#       C0015684|S0418706|17|fatty acid|NCI_NCI-GLOSS|PT
#       C0015684|S0418706|18|fatty acid|MMSL|IN
#       C0015684|S2228055|19|FATTY ACID|VANDF|IN
#       C0015684|S6126086|20|Fatty Acid|NCI_CTRP|DN
#       C0015684|S6126086|21|Fatty Acid|NCI|PT
#   "composition"
#     start: 1157
#     end: 1168
#     postings:
#       C0486616|S1937865|1|Composition|NCI|PT
#       C0486616|S1937865|2|Composition|LNC|LPN
#       C0486616|S1937865|3|Composition|LCH|PT
#       C0486616|S1937865|4|Composition|LNC|CN
#       C0486616|S1937865|5|Composition|NCI_CDISC|SY
#       C0486616|S1937865|6|Composition|NCI_CDISC|PT
#       C0486616|S1937865|7|Composition|MTH|PN
#       C0486616|S6325206|8|composition|CHV|PT
#       C1555710|S6325206|2|composition|HL7V3.0|PT
#   "fatty acid"
#     start: 1174
#     end: 1184
#     postings:
#       C0015684|S0001341|13|Fatty acid|SNM|PT
#       C0015684|S0001341|14|Fatty acid|FMA|PT
#       C0015684|S0418706|15|fatty acid|CSP|PT
#       C0015684|S0418706|16|fatty acid|CHV|PT
#       C0015684|S0418706|17|fatty acid|NCI_NCI-GLOSS|PT
#       C0015684|S0418706|18|fatty acid|MMSL|IN
#       C0015684|S2228055|19|FATTY ACID|VANDF|IN
#       C0015684|S6126086|20|Fatty Acid|NCI_CTRP|DN
#       C0015684|S6126086|21|Fatty Acid|NCI|PT
#   "cell"
#     start: 1201
#     end: 1205
#     postings:
#       C0007634|S0002474|12|Cell|MSH|PM
#       C0007634|S0002474|13|Cell|SNM|PT
#       C0007634|S0002474|14|Cell|FMA|PT
#       C0007634|S0002474|15|Cell|NCI|SY
#       C0007634|S0002474|16|Cell|UWDA|PT
#       C0007634|S0002474|17|Cell|NCI|PT
#       C0007634|S0002474|18|Cell|CPM|PT
#       C0007634|S0416322|20|cell|CSP|PT
#       C0007634|S0416322|21|cell|GO|PT
#       C0007634|S0416322|22|cell|CHV|PT
#       C0007634|S0416322|23|cell|NCI_NCI-GLOSS|PT
#       C1136359|S0002474|9|Cell|NCI|SY
#       C1413336|S7484925|3|CELL|OMIM|ACR
#       C1704653|S0002474|3|Cell|NCI_FDA|PT
#       C1704653|S0002474|4|Cell|NCI|SY
#       C1948049|S0002474|2|Cell|NCI|PT
#   "phospholipids"
#     start: 1206
#     end: 1219
#     postings:
#       C0031676|S1436372|1|phospholipids|AOD|DE
#       C0031676|S1436372|2|phospholipids|CHV|SY
#       C0031676|S1436372|3|phospholipids|NDDF|IN
#       C0031676|S1436372|4|phospholipids|MTH|PN
#       C0031676|S0073338|5|Phospholipids|LCH|PT
#       C0031676|S0073338|6|Phospholipids|MSH|MH
#       C0031676|S0073338|7|Phospholipids|NCI|SY
#       C0031676|S0073338|8|Phospholipids|LCH_NW|PT
#       C0031676|S0073338|9|Phospholipids|DRUGBANK|SY
#       C0031676|S0073338|10|Phospholipids|PSY|ET
#       C0031676|S0073338|11|Phospholipids|RXNORM|IN
#       C0031676|S2240514|12|PHOSPHOLIPIDS|VANDF|IN
#   "constant"
#     start: 1236
#     end: 1244
#     postings:
#       C1948059|S6984181|4|Constant|NCI|SY
#       C1948059|S6984181|5|Constant|NCI|PT
# sentence: "We conclude that the
# function of the cells is affected by the growth environment,
# particularly serum; that a short exposure to a uniform chemically
# defined medium is not sufficient to reverse these effects; and that
# the differences in effects are not the result of changes in the fatty
# acid composition of the whole cell phospholipids nor in mitochondrial
# membrane permeability as measured by nitroblue tetrazolium., 1246"
#   "function"
#     start: 1267
#     end: 1275
#     postings:
#       C0031843|S0419030|4|function|MSH|XQ
#       C0542341|S0889212|3|Function|RCD|AT
#       C0542341|S0889212|4|Function|NCI|SY
#       C0542341|S0889212|5|Function|LNC|LPN
#       C0542341|S0889212|6|Function|LNC|LA
#       C0542341|S0889212|7|Function|NCI|PT
#       C0542341|S0325059|8|FUNCTION|LNC|LPN
#       C0542341|S0419030|9|function|CHV|PT
#       C0542341|S0419030|10|function|CHV|PT
#       C1315032|S0325059|2|FUNCTION|LNC|HS
#       C1705273|S0889212|4|Function|NCI|SY
#   "cells"
#     start: 1283
#     end: 1288
#     postings:
#       C0007584|S0023469|17|Cells|NCI_CDISC|SY
#       C0007584|S0023469|18|Cells|NCI_CDISC|PT
#       C0007584|S0827167|19|CELLS|NCI_CDISC|PT
#       C0007634|S0023469|1|Cells|LCH|PT
#       C0007634|S0023469|2|Cells|MSH|MH
#       C0007634|S0023469|3|Cells|MTH|SY
#       C0007634|S0023469|4|Cells|LNC|LPN
#       C0007634|S0023469|5|Cells|LNC|CN
#       C0007634|S0023469|6|Cells|LCH_NW|PT
#       C0007634|S0023469|7|Cells|NCI_UCUM|PT
#       C0007634|S0023469|8|Cells|NCI|SY
#       C0007634|S0023469|9|Cells|MTH|PN
#       C0007634|S11865336|10|cells|CHV|SY
#       C0007634|S11865336|11|cells|LNC|LPN
#   "growth"
#     start: 1308
#     end: 1314
#     postings:
#       C0018270|S0046170|1|Growth|LCH|PT
#       C0018270|S0046170|2|Growth|MSH|MH
#       C0018270|S0046170|3|Growth|NCI|SY
#       C0018270|S0046170|4|Growth|LCH_NW|PT
#       C0018270|S0046170|5|Growth|NANDA-I|HC
#       C0018270|S0046170|6|Growth|NOC|OC
#       C0018270|S0046170|7|Growth|NOC|ID
#       C0018270|S0046170|8|Growth|NOC|ID
#       C0018270|S0046170|9|Growth|NOC|ID
#       C0018270|S0046170|10|Growth|PSY|ET
#       C0018270|S0046170|11|Growth|MTH|PN
#       C0018270|S0419586|12|growth|CHV|SY
#       C0018270|S0419586|13|growth|GO|PT
#       C0018270|S0890927|14|GROWTH|OMIM|HT
#       C0220844|S0419586|2|growth|MSH|PXQ
#       C1457898|S0890927|2|GROWTH|MSH|QEV
#       C1621966|S0046170|3|Growth|NCI|SY
#       C2911660|S0046170|2|Growth|NCI|PT
#   "environment"
#     start: 1315
#     end: 1326
#     postings:
#       C0014406|S0038087|1|Environment|MSH|MH
#       C0014406|S0038087|2|Environment|LNC|LPN
#       C0014406|S0038087|3|Environment|LNC|CN
#       C0014406|S0038087|4|Environment|MEDCIN|PT
#       C0014406|S0038087|5|Environment|PSY|PT
#       C0014406|S0038087|6|Environment|NCI|PT
#       C0014406|S0038087|7|Environment|MTH|PN
#       C0014406|S0418349|8|environment|AOD|DE
#       C0014406|S0418349|9|environment|CSP|PT
#       C0014406|S0418349|10|environment|OMS|TG
#       C0014406|S0418349|11|environment|CHV|PT
#   "serum"
#     start: 1341
#     end: 1346
#     postings:
#       C0229671|S0403972|1|Serum|RCD|PT
#       C0229671|S0403972|2|Serum|SNM|PT
#       C0229671|S0403972|3|Serum|LNC|LPN
#       C0229671|S0403972|4|Serum|LNC|LS
#       C0229671|S0403972|5|Serum|LCH_NW|PT
#       C0229671|S0403972|6|Serum|NCI|SY
#       C0229671|S0403972|7|Serum|UWDA|PT
#       C0229671|S0403972|8|Serum|FMA|SY
#       C0229671|S0403972|9|Serum|MSH|MH
#       C0229671|S0403972|10|Serum|NCI|PT
#       C0229671|S0403972|11|Serum|MTH|PN
#       C0229671|S0401563|12|SERUM|NCI_CDISC|PT
#       C0229671|S1239724|13|serum|AOD|DE
#       C0229671|S1239724|14|serum|CSP|PT
#       C0229671|S1239724|15|serum|CHV|PT
#       C0229671|S1239724|16|serum|NCI_NCI-GLOSS|PT
#       C1546774|S0403972|2|Serum|HL7V2.5|PT
#       C1550100|S0403972|2|Serum|HL7V3.0|PT
#   "short"
#     start: 1355
#     end: 1360
#     postings:
#       C1282927|S11937743|5|short|CHV|PT
#       C1806781|S0324587|1|Short|RCD|PT
#       C1806781|S0324587|2|Short|OMIM|PTCS
#       C1806781|S0324587|3|Short|LNC|LA
#       C1806781|S0324587|4|Short|NCI|PT
#       C1806781|S0324587|5|Short|MTH|PN
#       C1806781|S16093322|6|SHORT|NCI_CDISC|PT
#       C2350002|S0324587|3|Short|NCI|PT
#   "exposure to"
#     start: 1361
#     end: 1372
#     postings:
#       C0332157|S0642558|1|Exposure to|MTH|PN
#       C0332157|S11885829|2|exposure to|CHV|SY
#   "uniform"
#     start: 1375
#     end: 1382
#     postings:
#       C0205375|S0324800|2|Uniform|RCD|PT
#       C0205375|S0324800|3|Uniform|NCI|PT
#       C0205375|S6325967|4|uniform|CHV|PT
#       C1608508|S6325967|2|uniform|HL7V3.0|PT
#       C4019284|S0324800|3|Uniform|MSH|PM
#   "chemically"
#     start: 1383
#     end: 1393
#     postings:
#       C0220806|S7669275|24|Chemically|NCI|AD
#   "defined"
#     start: 1394
#     end: 1401
#     postings:
#       C1704788|S7670164|5|Defined|NCI|AD
#       C4724435|S7670164|3|Defined|NCI|SY
#   "medium"
#     start: 1402
#     end: 1408
#     postings:
#       C0009458|S0943869|11|Medium|NCI|SY
#       C0439536|S0943869|1|Medium|RCD|PT
#       C0439536|S0943869|2|Medium|NCI|PT
#       C0439536|S0943869|3|Medium|NCI|SY
#       C0439536|S0943869|4|Medium|LNC|LA
#       C0439536|S0943869|5|Medium|MTH|PN
#       C0439536|S11912821|6|medium|CHV|PT
#       C0439536|S6941619|7|MEDIUM|NCI_CDISC|PT
#       C1561547|S0943869|2|Medium|HL7V3.0|PT
#       C1705217|S0943869|2|Medium|NCI|PT
#       C3244283|S11912821|2|medium|HL7V3.0|PT
#       C4085196|S0943869|3|Medium|NCI|SY
#       C4522282|S0943869|3|Medium|NCI|SY
#       C4522283|S0943869|4|Medium|NCI|SY
#       C4722268|S0943869|3|Medium|NCI|SY
#   "not"
#     start: 1412
#     end: 1415
#     postings:
#       C1417836|S7299739|7|NOT|HGNC|SYN
#       C1417836|S7299739|8|NOT|OMIM|ACR
#       C1518422|S6136096|9|Not|NCI|AD
#       C1518422|S6136096|10|Not|NCI|SY
#       C1518422|S6136096|11|Not|NCI|SY
#       C1518422|S6136096|12|Not|LNC|LA
#       C1518422|S6136096|13|Not|NCI|SY
#   "sufficient"
#     start: 1416
#     end: 1426
#     postings:
#       C0205410|S0324836|1|Sufficient|NCI|PT
#       C0205410|S0324836|2|Sufficient|NCI|SY
#       C0205410|S0324836|3|Sufficient|LNC|LA
#       C0205410|S0324836|4|Sufficient|MTH|PN
#       C0205410|S11942554|5|sufficient|CHV|PT
#   "effects"
#     start: 1444
#     end: 1451
#     postings:
#       C1280500|S11882510|4|effects|CHV|SY
#       C1280500|S14453944|5|Effects|NCI|SY
#   "effects"
#     start: 1481
#     end: 1488
#     postings:
#       C1280500|S11882510|4|effects|CHV|SY
#       C1280500|S14453944|5|Effects|NCI|SY
#   "not"
#     start: 1493
#     end: 1496
#     postings:
#       C1417836|S7299739|7|NOT|HGNC|SYN
#       C1417836|S7299739|8|NOT|OMIM|ACR
#       C1518422|S6136096|9|Not|NCI|AD
#       C1518422|S6136096|10|Not|NCI|SY
#       C1518422|S6136096|11|Not|NCI|SY
#       C1518422|S6136096|12|Not|LNC|LA
#       C1518422|S6136096|13|Not|NCI|SY
#   "result"
#     start: 1501
#     end: 1507
#     postings:
#       C1274040|S3513919|1|Result|NCI|SY
#       C1274040|S3513919|2|Result|MTH|PN
#       C1274040|S6175685|3|result|NCI_BRIDG_3_0_3|PT
#       C1546471|S3513919|2|Result|HL7V2.5|PT
#       C2825142|S3513919|3|Result|NCI|SY
#   "changes"
#     start: 1511
#     end: 1518
#     postings:
#       C0392747|S11866307|6|changes|CHV|SY
#       C0443172|S11866307|7|changes|CHV|SY
#   "fatty acid"
#     start: 1526
#     end: 1536
#     postings:
#       C0015684|S0001341|13|Fatty acid|SNM|PT
#       C0015684|S0001341|14|Fatty acid|FMA|PT
#       C0015684|S0418706|15|fatty acid|CSP|PT
#       C0015684|S0418706|16|fatty acid|CHV|PT
#       C0015684|S0418706|17|fatty acid|NCI_NCI-GLOSS|PT
#       C0015684|S0418706|18|fatty acid|MMSL|IN
#       C0015684|S2228055|19|FATTY ACID|VANDF|IN
#       C0015684|S6126086|20|Fatty Acid|NCI_CTRP|DN
#       C0015684|S6126086|21|Fatty Acid|NCI|PT
#   "composition"
#     start: 1537
#     end: 1548
#     postings:
#       C0486616|S1937865|1|Composition|NCI|PT
#       C0486616|S1937865|2|Composition|LNC|LPN
#       C0486616|S1937865|3|Composition|LCH|PT
#       C0486616|S1937865|4|Composition|LNC|CN
#       C0486616|S1937865|5|Composition|NCI_CDISC|SY
#       C0486616|S1937865|6|Composition|NCI_CDISC|PT
#       C0486616|S1937865|7|Composition|MTH|PN
#       C0486616|S6325206|8|composition|CHV|PT
#       C1555710|S6325206|2|composition|HL7V3.0|PT
#   "whole"
#     start: 1556
#     end: 1561
#     postings:
#       C0444667|S1063448|1|Whole|RCD|PT
#       C0444667|S1063448|2|Whole|NCI_CDISC|SY
#       C0444667|S1063448|3|Whole|NCI|PT
#       C0444667|S1063448|4|Whole|MTH|PN
#       C0444667|S11952962|5|whole|CHV|PT
#   "cell"
#     start: 1562
#     end: 1566
#     postings:
#       C0007634|S0002474|12|Cell|MSH|PM
#       C0007634|S0002474|13|Cell|SNM|PT
#       C0007634|S0002474|14|Cell|FMA|PT
#       C0007634|S0002474|15|Cell|NCI|SY
#       C0007634|S0002474|16|Cell|UWDA|PT
#       C0007634|S0002474|17|Cell|NCI|PT
#       C0007634|S0002474|18|Cell|CPM|PT
#       C0007634|S0416322|20|cell|CSP|PT
#       C0007634|S0416322|21|cell|GO|PT
#       C0007634|S0416322|22|cell|CHV|PT
#       C0007634|S0416322|23|cell|NCI_NCI-GLOSS|PT
#       C1136359|S0002474|9|Cell|NCI|SY
#       C1413336|S7484925|3|CELL|OMIM|ACR
#       C1704653|S0002474|3|Cell|NCI_FDA|PT
#       C1704653|S0002474|4|Cell|NCI|SY
#       C1948049|S0002474|2|Cell|NCI|PT
#   "phospholipids"
#     start: 1567
#     end: 1580
#     postings:
#       C0031676|S1436372|1|phospholipids|AOD|DE
#       C0031676|S1436372|2|phospholipids|CHV|SY
#       C0031676|S1436372|3|phospholipids|NDDF|IN
#       C0031676|S1436372|4|phospholipids|MTH|PN
#       C0031676|S0073338|5|Phospholipids|LCH|PT
#       C0031676|S0073338|6|Phospholipids|MSH|MH
#       C0031676|S0073338|7|Phospholipids|NCI|SY
#       C0031676|S0073338|8|Phospholipids|LCH_NW|PT
#       C0031676|S0073338|9|Phospholipids|DRUGBANK|SY
#       C0031676|S0073338|10|Phospholipids|PSY|ET
#       C0031676|S0073338|11|Phospholipids|RXNORM|IN
#       C0031676|S2240514|12|PHOSPHOLIPIDS|VANDF|IN
#   "mitochondrial membrane"
#     start: 1588
#     end: 1610
#     postings:
#       C0596952|S1234365|3|mitochondrial membrane|CSP|PT
#       C0596952|S1234365|4|mitochondrial membrane|GO|PT
#       C0596952|S3011716|5|Mitochondrial membrane|UWDA|SY
#       C0596952|S3011716|6|Mitochondrial membrane|FMA|SY
#       C0596952|S6133573|7|Mitochondrial Membrane|MSH|PM
#       C0596952|S6133573|8|Mitochondrial Membrane|NCI|PT
#   "nitroblue tetrazolium"
#     start: 1639
#     end: 1660
#     postings:
#       C0028147|S0066863|1|Nitroblue Tetrazolium|MSH|MH
#       C0028147|S1235878|2|nitroblue tetrazolium|CHV|PT

# %%
inputtext[1639:1660]
# Out:
# 'nitroblue tetrazolium'

# %%
inputtext[821:831]
# Out:
# 'deficiency'
