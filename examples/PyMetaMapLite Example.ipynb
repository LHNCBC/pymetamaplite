# %% [markdown]
# # PyMetaMapLite Example

# %%
from collections import namedtuple
import nltk
from nltk.tokenize import TreebankWordTokenizer
from metamaplite import MetaMapLite, postings_utils

# %%
def loadtextfile(inputfile):
    """ Load textfile and return as string """
    text = ''
    with open(inputfile) as fp:
        text = fp.read()
    return text

# %% [markdown]
# Load input text:

# %%
inputfilename = 'neonatal2.txt'
inputtext = loadtextfile(inputfilename)

# %% [markdown]
# Location of MetaMapLite UMLS indexes:

# %%
ivfdir = 'pathto/public_mm_lite/data/ivf/2020AA/USAbase'

# %% [markdown]
# Assign allowed vocabulary source list, semantic type list, stopwords, and term excluded by concept unique identifer.

# %%
use_sources = []
use_semtypes = []
stopwords = []
excludedterms = []

# %% [markdown]
# The token's part-of-speech must be in postags set to be looked up in dictionary.

# %%
postags = set(["CD", "FW", "RB", "IN", "NN", "NNS",
               "NNP", "NNPS", "JJ", "JJR", "JJS", "LS"])

# %% [markdown]
# Instantiate a MetaMapLite instance.

# %%
mminst = MetaMapLite(ivfdir, use_sources, use_semtypes, postags,
                     stopwords, excludedterms)

# %% [markdown]
# Named tuple ``Token`` contains token text in ``text``, part of speech tag  in ``tag_``, and charater offset is in ``idx``.

# %%
Token = namedtuple('Token', ['text', 'tag_', 'idx'])

# %%
inputtext
# Out:
# "The 24-h period of exposure to chemically defined medium was not\nsufficient to reverse the effects imposed on the cells by the serum\nused in the first phase of growth. Effect of change in growth\nenvironment on cultured myocardial cells investigated in a\nstandardized medium. Neonatal rat heart cells cultivated in either of\ntwo different media which varied only in their serum supplements were\ntransferred to chemically defined medium (Ham's F10) for 24 h before\nmeasuring a variety of parameters. The 24-h period of exposure to\nchemically defined medium was not sufficient to reverse the effects\nimposed on the cells by the serum used in the first phase of\ngrowth. The cells differed in rate and duration of action potentials\nand contractions. The initial serum composition affected the response\nof the cells to calcium deficiency. Studies involving the effects of\npharmaceutical reagents such as isoproterenol were also influenced by\nthe serum. In attempting to determine the cause and possible\nmechanism, it was found that mitochondrial membrane permeability for\nnitroblue tetrazolium was unchanged. Although the serum supplements\ndiffered in fatty acid composition, the fatty acid profiles of the\ncell phospholipids were relatively constant. We conclude that the\nfunction of the cells is affected by the growth environment,\nparticularly serum; that a short exposure to a uniform chemically\ndefined medium is not sufficient to reverse these effects; and that\nthe differences in effects are not the result of changes in the fatty\nacid composition of the whole cell phospholipids nor in mitochondrial\nmembrane permeability as measured by nitroblue tetrazolium.\n"

# %% [markdown]
# Convert text into sentences, tokenize each sentence, and apply part-of-speech tagger to each list of sentence tokens.  Then apply recognizer to tagged tokenlist.

# %%
sentlist = nltk.sent_tokenize(inputtext)
sent_resultlist = []
sentidx = 0
for sentence in sentlist:
    spanlist = list(TreebankWordTokenizer().span_tokenize(sentence))
    texttokenlist = [sentence[start:end] for start, end in spanlist]
    
    postokenlist = nltk.pos_tag(texttokenlist)
    tokenlist = []
    for token, span in zip(postokenlist, spanlist):
        tokenlist.append(Token(text=token[0], tag_=token[1],
                               idx=(sentidx+span[0])))
    matches = mminst.get_entities(tokenlist, span_info=True)
    sent_resultlist.append(((sentence, sentidx), matches))
    sentidx = sentidx + len(sentence) + 1

# %%
len(sentlist), len(sent_resultlist)
# Out:
# (10, 10)

# %%
def display_results(mminst, sent_resultlist):
    """ process inputtext returning list of matches """
    for sentence, matches in sent_resultlist:
        print('sentence: "%s, %d"' % sentence)
        for term in matches:
            print('  "%s"' % term.text)
            print('    start: %d' % term.start)
            print('    end: %d' % term.end)
            print('    postings:')
            for post in postings_utils.add_semantic_types(mminst, term.postings):
                print('      {}'.format(post))

# %%
display_results(mminst, sent_resultlist)
# Out:
# sentence: "The 24-h period of exposure to chemically defined medium was not
# sufficient to reverse the effects imposed on the cells by the serum
# used in the first phase of growth., 0"
#   "period"
#     start: 9
#     end: 15
#     postings:
#       PostingSTS(cui='C0025344', sui='S1237140', idx='41', str='period', src='CHV', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0025344', sui='S6137818', idx='42', str='Period', src='MEDLINEPLUS', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0439531', sui='S1237140', idx='4', str='period', src='CHV', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C1561960', sui='S1237140', idx='2', str='period', src='HL7V3.0', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1948053', sui='S6137818', idx='2', str='Period', src='NCI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C2347804', sui='S6137818', idx='3', str='Period', src='NCI', termtype='SY', semtypeset=['resa'])
#   "exposure to"
#     start: 19
#     end: 30
#     postings:
#       PostingSTS(cui='C0332157', sui='S0642558', idx='1', str='Exposure to', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S0642558', idx='2', str='Exposure to', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S0642558', idx='3', str='Exposure to', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S11885829', idx='4', str='exposure to', src='CHV', termtype='SY', semtypeset=['qlco'])
#   "chemically"
#     start: 31
#     end: 41
#     postings:
#       PostingSTS(cui='C0220806', sui='S7669275', idx='39', str='Chemically', src='NCI', termtype='AD', semtypeset=['chem'])
#   "defined"
#     start: 42
#     end: 49
#     postings:
#       PostingSTS(cui='C1704788', sui='S7670164', idx='5', str='Defined', src='NCI', termtype='AD', semtypeset=['inpr'])
#       PostingSTS(cui='C3539106', sui='S7670164', idx='7', str='Defined', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C4724435', sui='S7670164', idx='3', str='Defined', src='NCI', termtype='SY', semtypeset=['cnce'])
#   "medium"
#     start: 50
#     end: 56
#     postings:
#       PostingSTS(cui='C0009458', sui='S0943869', idx='9', str='Medium', src='NCI', termtype='SY', semtypeset=['inpr'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='1', str='Medium', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='3', str='Medium', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='4', str='Medium', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='5', str='Medium', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S11912821', idx='6', str='medium', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S6941619', idx='7', str='MEDIUM', src='NCI_CDISC', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1561547', sui='S0943869', idx='2', str='Medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1705217', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='PT', semtypeset=['sbst'])
#       PostingSTS(cui='C3244283', sui='S11912821', idx='2', str='medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C4085196', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['cnce'])
#       PostingSTS(cui='C4522282', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4522283', sui='S0943869', idx='4', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4722268', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#   "not"
#     start: 61
#     end: 64
#     postings:
#       PostingSTS(cui='C1417836', sui='S7299739', idx='7', str='NOT', src='HGNC', termtype='SYN', semtypeset=['gngm'])
#       PostingSTS(cui='C1417836', sui='S7299739', idx='8', str='NOT', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='9', str='Not', src='NCI', termtype='AD', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='10', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='11', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='12', str='Not', src='LNC', termtype='LA', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='13', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#   "sufficient"
#     start: 65
#     end: 75
#     postings:
#       PostingSTS(cui='C0205410', sui='S0324836', idx='1', str='Sufficient', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='2', str='Sufficient', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='3', str='Sufficient', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='4', str='Sufficient', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='5', str='Sufficient', src='LNC', termtype='LA', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='6', str='Sufficient', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S11942554', idx='7', str='sufficient', src='CHV', termtype='PT', semtypeset=['qlco'])
#   "effects"
#     start: 91
#     end: 98
#     postings:
#       PostingSTS(cui='C1280500', sui='S11882510', idx='7', str='effects', src='CHV', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S14453944', idx='8', str='Effects', src='NCI', termtype='SY', semtypeset=['qlco'])
#   "cells"
#     start: 114
#     end: 119
#     postings:
#       PostingSTS(cui='C0007584', sui='S0023469', idx='24', str='Cells', src='NCI_CDISC', termtype='SY', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0023469', idx='25', str='Cells', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0827167', idx='26', str='CELLS', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='1', str='Cells', src='LCH', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='2', str='Cells', src='MSH', termtype='MH', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='3', str='Cells', src='MTH', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='4', str='Cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='5', str='Cells', src='LNC', termtype='CN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='6', str='Cells', src='LCH_NW', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='7', str='Cells', src='NCI_UCUM', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='8', str='Cells', src='NCI', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='9', str='Cells', src='MTH', termtype='PN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='10', str='cells', src='CHV', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='11', str='cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#   "serum"
#     start: 127
#     end: 132
#     postings:
#       PostingSTS(cui='C0229671', sui='S0403972', idx='1', str='Serum', src='SNM', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='2', str='Serum', src='SNMI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='3', str='Serum', src='LNC', termtype='LPN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='4', str='Serum', src='LNC', termtype='LS', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='5', str='Serum', src='LCH_NW', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='6', str='Serum', src='NCI', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='7', str='Serum', src='UWDA', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='8', str='Serum', src='FMA', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='9', str='Serum', src='MSH', termtype='MH', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='10', str='Serum', src='SNOMEDCT_US', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='11', str='Serum', src='NCI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='12', str='Serum', src='MTH', termtype='PN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0401563', idx='13', str='SERUM', src='NCI_CDISC', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='14', str='serum', src='AOD', termtype='DE', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='15', str='serum', src='CSP', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='16', str='serum', src='CHV', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='17', str='serum', src='NCI_NCI-GLOSS', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C1546774', sui='S0403972', idx='2', str='Serum', src='HL7V2.5', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C1550100', sui='S0403972', idx='2', str='Serum', src='HL7V3.0', termtype='PT', semtypeset=['bdsu'])
#   "first"
#     start: 145
#     end: 150
#     postings:
#       PostingSTS(cui='C0205435', sui='S0324862', idx='2', str='First', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0205435', sui='S11889009', idx='3', str='first', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='6', str='First', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='7', str='First', src='SNOMEDCT_US', termtype='OAP', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='8', str='First', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='9', str='First', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='10', str='First', src='NCI', termtype='PT', semtypeset=['qlco'])
#   "phase"
#     start: 151
#     end: 156
#     postings:
#       PostingSTS(cui='C0205390', sui='S0324816', idx='1', str='Phase', src='SNMI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='2', str='Phase', src='SNOMEDCT_US', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='3', str='Phase', src='NCI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='4', str='Phase', src='MTH', termtype='PN', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S1237339', idx='5', str='phase', src='CHV', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C1710475', sui='S1237339', idx='4', str='phase', src='NCI_CDISC-GLOSS', termtype='PT', semtypeset=['clas'])
#   "growth"
#     start: 160
#     end: 166
#     postings:
#       PostingSTS(cui='C0018270', sui='S0046170', idx='1', str='Growth', src='LCH', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='2', str='Growth', src='MSH', termtype='MH', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='4', str='Growth', src='LCH_NW', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='5', str='Growth', src='MTH', termtype='PN', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='6', str='growth', src='CHV', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='7', str='growth', src='GO', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0890927', idx='8', str='GROWTH', src='OMIM', termtype='HT', semtypeset=['orgf'])
#       PostingSTS(cui='C0220844', sui='S0419586', idx='2', str='growth', src='MSH', termtype='PXQ', semtypeset=['phsf'])
#       PostingSTS(cui='C1457898', sui='S0890927', idx='2', str='GROWTH', src='MSH', termtype='QEV', semtypeset=['fndg'])
#       PostingSTS(cui='C1621966', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['ortf'])
#       PostingSTS(cui='C2911660', sui='S0046170', idx='2', str='Growth', src='NCI', termtype='PT', semtypeset=['phpr'])
# sentence: "Effect of change in growth
# environment on cultured myocardial cells investigated in a
# standardized medium., 168"
#   "Effect"
#     start: 168
#     end: 174
#     postings:
#       PostingSTS(cui='C1280500', sui='S0637364', idx='1', str='Effect', src='SNMI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S0637364', idx='2', str='Effect', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S0637364', idx='3', str='Effect', src='SNOMEDCT_US', termtype='IS', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S0637364', idx='4', str='Effect', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S0637364', idx='5', str='Effect', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S11882511', idx='6', str='effect', src='CHV', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1518681', sui='S11882511', idx='4', str='effect', src='NCI_CDISC-GLOSS', termtype='PT', semtypeset=['fndg'])
#       PostingSTS(cui='C2348382', sui='S0637364', idx='3', str='Effect', src='NCI', termtype='SY', semtypeset=['qlco'])
#   "change in"
#     start: 178
#     end: 187
#     postings:
#       PostingSTS(cui='C0392747', sui='S0835540', idx='9', str='Change in', src='SNOMEDCT_US', termtype='IS', semtypeset=['ftcn'])
#       PostingSTS(cui='C0392747', sui='S0835540', idx='10', str='Change in', src='SNMI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C0392747', sui='S11866223', idx='11', str='change in', src='CHV', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C0443172', sui='S0835540', idx='4', str='Change in', src='SNOMEDCT_US', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0443172', sui='S11866223', idx='5', str='change in', src='CHV', termtype='SY', semtypeset=['qnco'])
#   "growth"
#     start: 188
#     end: 194
#     postings:
#       PostingSTS(cui='C0018270', sui='S0046170', idx='1', str='Growth', src='LCH', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='2', str='Growth', src='MSH', termtype='MH', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='4', str='Growth', src='LCH_NW', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='5', str='Growth', src='MTH', termtype='PN', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='6', str='growth', src='CHV', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='7', str='growth', src='GO', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0890927', idx='8', str='GROWTH', src='OMIM', termtype='HT', semtypeset=['orgf'])
#       PostingSTS(cui='C0220844', sui='S0419586', idx='2', str='growth', src='MSH', termtype='PXQ', semtypeset=['phsf'])
#       PostingSTS(cui='C1457898', sui='S0890927', idx='2', str='GROWTH', src='MSH', termtype='QEV', semtypeset=['fndg'])
#       PostingSTS(cui='C1621966', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['ortf'])
#       PostingSTS(cui='C2911660', sui='S0046170', idx='2', str='Growth', src='NCI', termtype='PT', semtypeset=['phpr'])
#   "environment"
#     start: 195
#     end: 206
#     postings:
#       PostingSTS(cui='C0014406', sui='S0038087', idx='1', str='Environment', src='MSH', termtype='MH', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0038087', idx='2', str='Environment', src='LNC', termtype='LPN', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0038087', idx='3', str='Environment', src='LNC', termtype='CN', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0038087', idx='4', str='Environment', src='NCI', termtype='PT', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0038087', idx='5', str='Environment', src='SNOMEDCT_US', termtype='PT', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0038087', idx='6', str='Environment', src='MTH', termtype='PN', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0418349', idx='7', str='environment', src='AOD', termtype='DE', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0418349', idx='8', str='environment', src='CSP', termtype='PT', semtypeset=['spco'])
#       PostingSTS(cui='C0014406', sui='S0418349', idx='9', str='environment', src='CHV', termtype='PT', semtypeset=['spco'])
#   "myocardial"
#     start: 219
#     end: 229
#     postings:
#       PostingSTS(cui='C0027061', sui='S0388775', idx='36', str='Myocardial', src='SNMI', termtype='AD', semtypeset=['tisu'])
#       PostingSTS(cui='C1522564', sui='S0388775', idx='1', str='Myocardial', src='NCI', termtype='PT', semtypeset=['spco'])
#       PostingSTS(cui='C1522564', sui='S0388775', idx='2', str='Myocardial', src='MTH', termtype='PN', semtypeset=['spco'])
#   "cells"
#     start: 230
#     end: 235
#     postings:
#       PostingSTS(cui='C0007584', sui='S0023469', idx='24', str='Cells', src='NCI_CDISC', termtype='SY', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0023469', idx='25', str='Cells', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0827167', idx='26', str='CELLS', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='1', str='Cells', src='LCH', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='2', str='Cells', src='MSH', termtype='MH', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='3', str='Cells', src='MTH', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='4', str='Cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='5', str='Cells', src='LNC', termtype='CN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='6', str='Cells', src='LCH_NW', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='7', str='Cells', src='NCI_UCUM', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='8', str='Cells', src='NCI', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='9', str='Cells', src='MTH', termtype='PN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='10', str='cells', src='CHV', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='11', str='cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#   "medium"
#     start: 267
#     end: 273
#     postings:
#       PostingSTS(cui='C0009458', sui='S0943869', idx='9', str='Medium', src='NCI', termtype='SY', semtypeset=['inpr'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='1', str='Medium', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='3', str='Medium', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='4', str='Medium', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='5', str='Medium', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S11912821', idx='6', str='medium', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S6941619', idx='7', str='MEDIUM', src='NCI_CDISC', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1561547', sui='S0943869', idx='2', str='Medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1705217', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='PT', semtypeset=['sbst'])
#       PostingSTS(cui='C3244283', sui='S11912821', idx='2', str='medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C4085196', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['cnce'])
#       PostingSTS(cui='C4522282', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4522283', sui='S0943869', idx='4', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4722268', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
# sentence: "Neonatal rat heart cells cultivated in either of
# two different media which varied only in their serum supplements were
# transferred to chemically defined medium (Ham's F10) for 24 h before
# measuring a variety of parameters., 275"
#   "Neonatal"
#     start: 275
#     end: 283
#     postings:
#       PostingSTS(cui='C0021289', sui='S0694910', idx='36', str='Neonatal', src='NCI', termtype='AD', semtypeset=['aggp'])
#       PostingSTS(cui='C2939425', sui='S0694910', idx='8', str='Neonatal', src='SNMI', termtype='AD', semtypeset=['tmco'])
#       PostingSTS(cui='C2939425', sui='S0694910', idx='9', str='Neonatal', src='SNOMEDCT_US', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C2939425', sui='S11917591', idx='10', str='neonatal', src='CHV', termtype='PT', semtypeset=['tmco'])
#   "rat heart"
#     start: 284
#     end: 293
#     postings:
#       PostingSTS(cui='C1882687', sui='S7660100', idx='1', str='Rat Heart', src='NCI', termtype='PT', semtypeset=['bpoc'])
#   "two"
#     start: 324
#     end: 327
#     postings:
#       PostingSTS(cui='C0205448', sui='S0324875', idx='1', str='Two', src='SNMI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='2', str='Two', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='3', str='Two', src='LNC', termtype='LPN', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='4', str='Two', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='5', str='Two', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='6', str='Two', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='7', str='Two', src='SNOMEDCT_US', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0205448', sui='S0324875', idx='8', str='Two', src='MTH', termtype='PN', semtypeset=['qnco'])
#   "different"
#     start: 328
#     end: 337
#     postings:
#       PostingSTS(cui='C1705242', sui='S6936116', idx='1', str='Different', src='NCI', termtype='AD', semtypeset=['qlco'])
#       PostingSTS(cui='C1705242', sui='S6936116', idx='2', str='Different', src='MTH', termtype='PN', semtypeset=['qlco'])
#   "media"
#     start: 338
#     end: 343
#     postings:
#       PostingSTS(cui='C0009458', sui='S0387102', idx='8', str='Media', src='NCI', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C0162867', sui='S0387102', idx='11', str='Media', src='SNMI', termtype='SY', semtypeset=['tisu'])
#       PostingSTS(cui='C0162867', sui='S0387102', idx='12', str='Media', src='SNOMEDCT_US', termtype='SY', semtypeset=['tisu'])
#       PostingSTS(cui='C0677540', sui='S0387102', idx='2', str='Media', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C1254021', sui='S0387102', idx='3', str='Media', src='UWDA', termtype='PT', semtypeset=['tisu'])
#       PostingSTS(cui='C1254021', sui='S11912481', idx='4', str='media', src='CHV', termtype='PT', semtypeset=['tisu'])
#   "only"
#     start: 357
#     end: 361
#     postings:
#       PostingSTS(cui='C0205171', sui='S6991592', idx='20', str='Only', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C1720467', sui='S6991592', idx='4', str='Only', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#   "serum"
#     start: 371
#     end: 376
#     postings:
#       PostingSTS(cui='C0229671', sui='S0403972', idx='1', str='Serum', src='SNM', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='2', str='Serum', src='SNMI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='3', str='Serum', src='LNC', termtype='LPN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='4', str='Serum', src='LNC', termtype='LS', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='5', str='Serum', src='LCH_NW', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='6', str='Serum', src='NCI', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='7', str='Serum', src='UWDA', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='8', str='Serum', src='FMA', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='9', str='Serum', src='MSH', termtype='MH', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='10', str='Serum', src='SNOMEDCT_US', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='11', str='Serum', src='NCI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='12', str='Serum', src='MTH', termtype='PN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0401563', idx='13', str='SERUM', src='NCI_CDISC', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='14', str='serum', src='AOD', termtype='DE', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='15', str='serum', src='CSP', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='16', str='serum', src='CHV', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='17', str='serum', src='NCI_NCI-GLOSS', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C1546774', sui='S0403972', idx='2', str='Serum', src='HL7V2.5', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C1550100', sui='S0403972', idx='2', str='Serum', src='HL7V3.0', termtype='PT', semtypeset=['bdsu'])
#   "supplements"
#     start: 377
#     end: 388
#     postings:
#       PostingSTS(cui='C0242295', sui='S6142845', idx='46', str='Supplements', src='NCI_CPTAC', termtype='PT', semtypeset=['food'])
#   "chemically"
#     start: 409
#     end: 419
#     postings:
#       PostingSTS(cui='C0220806', sui='S7669275', idx='39', str='Chemically', src='NCI', termtype='AD', semtypeset=['chem'])
#   "defined"
#     start: 420
#     end: 427
#     postings:
#       PostingSTS(cui='C1704788', sui='S7670164', idx='5', str='Defined', src='NCI', termtype='AD', semtypeset=['inpr'])
#       PostingSTS(cui='C3539106', sui='S7670164', idx='7', str='Defined', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C4724435', sui='S7670164', idx='3', str='Defined', src='NCI', termtype='SY', semtypeset=['cnce'])
#   "medium"
#     start: 428
#     end: 434
#     postings:
#       PostingSTS(cui='C0009458', sui='S0943869', idx='9', str='Medium', src='NCI', termtype='SY', semtypeset=['inpr'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='1', str='Medium', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='3', str='Medium', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='4', str='Medium', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='5', str='Medium', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S11912821', idx='6', str='medium', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S6941619', idx='7', str='MEDIUM', src='NCI_CDISC', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1561547', sui='S0943869', idx='2', str='Medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1705217', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='PT', semtypeset=['sbst'])
#       PostingSTS(cui='C3244283', sui='S11912821', idx='2', str='medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C4085196', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['cnce'])
#       PostingSTS(cui='C4522282', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4522283', sui='S0943869', idx='4', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4722268', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#   "Ham"
#     start: 436
#     end: 439
#     postings:
#       PostingSTS(cui='C0030481', sui='S1640469', idx='60', str='HAM', src='OMIM', termtype='ACR', semtypeset=['dsyn'])
#       PostingSTS(cui='C0279477', sui='S1640469', idx='6', str='HAM', src='PDQ', termtype='AB', semtypeset=['topp'])
#       PostingSTS(cui='C0279477', sui='S1640469', idx='7', str='HAM', src='NCI', termtype='AB', semtypeset=['topp'])
#       PostingSTS(cui='C1570167', sui='S14774169', idx='8', str='hAM', src='NCI', termtype='SY', semtypeset=['aapp', 'bacs'])
#       PostingSTS(cui='C3853311', sui='S7441753', idx='1', str='Ham', src='LNC', termtype='LPN', semtypeset=['food'])
#       PostingSTS(cui='C3853311', sui='S7441753', idx='2', str='Ham', src='SNOMEDCT_US', termtype='PT', semtypeset=['food'])
#       PostingSTS(cui='C3853311', sui='S7441753', idx='3', str='Ham', src='MTH', termtype='PN', semtypeset=['food'])
#   "F10"
#     start: 442
#     end: 445
#     postings:
#       PostingSTS(cui='C1414497', sui='S7502946', idx='7', str='F10', src='NCI', termtype='SY', semtypeset=['gngm'])
#       PostingSTS(cui='C1414497', sui='S7502946', idx='8', str='F10', src='HGNC', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1414497', sui='S7502946', idx='9', str='F10', src='NCI_NCI-HGNC', termtype='PT', semtypeset=['gngm'])
#       PostingSTS(cui='C1414497', sui='S7502946', idx='10', str='F10', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#   "for"
#     start: 447
#     end: 450
#     postings:
#       PostingSTS(cui='C0521125', sui='S0887174', idx='2', str='For', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0521125', sui='S0887174', idx='3', str='For', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0521125', sui='S0887174', idx='4', str='For', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1421525', sui='S6926717', idx='4', str='FOR', src='HGNC', termtype='SYN', semtypeset=['gngm'])
#       PostingSTS(cui='C1421525', sui='S6926717', idx='5', str='FOR', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1562169', sui='S6926717', idx='4', str='FOR', src='AOT', termtype='ET', semtypeset=['topp'])
#       PostingSTS(cui='C4321252', sui='S6926717', idx='3', str='FOR', src='NCI', termtype='SY', semtypeset=['gngm'])
#   "before"
#     start: 456
#     end: 462
#     postings:
#       PostingSTS(cui='C0332152', sui='S0597822', idx='1', str='Before', src='SNMI', termtype='SY', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S0597822', idx='2', str='Before', src='NCI', termtype='SY', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S0597822', idx='3', str='Before', src='SNOMEDCT_US', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S0597822', idx='4', str='Before', src='SNOMEDCT_US', termtype='IS', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S0597822', idx='5', str='Before', src='MTH', termtype='PN', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S11855275', idx='6', str='before', src='CHV', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0332152', sui='S6931593', idx='7', str='BEFORE', src='NCI_CDISC', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C1705850', sui='S0597822', idx='3', str='Before', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#   "variety"
#     start: 475
#     end: 482
#     postings:
#       PostingSTS(cui='C1883525', sui='S7662720', idx='3', str='Variety', src='NCI', termtype='PT', semtypeset=['cnce'])
#       PostingSTS(cui='C2346866', sui='S7662720', idx='3', str='Variety', src='NCI', termtype='SY', semtypeset=['cnce'])
#   "parameters"
#     start: 486
#     end: 496
#     postings:
#       PostingSTS(cui='C0449381', sui='S0983567', idx='4', str='Parameters', src='SNOMEDCT_US', termtype='SY', semtypeset=['fndg'])
# sentence: "The 24-h period of exposure to
# chemically defined medium was not sufficient to reverse the effects
# imposed on the cells by the serum used in the first phase of
# growth., 498"
#   "period"
#     start: 507
#     end: 513
#     postings:
#       PostingSTS(cui='C0025344', sui='S1237140', idx='41', str='period', src='CHV', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0025344', sui='S6137818', idx='42', str='Period', src='MEDLINEPLUS', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0439531', sui='S1237140', idx='4', str='period', src='CHV', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C1561960', sui='S1237140', idx='2', str='period', src='HL7V3.0', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1948053', sui='S6137818', idx='2', str='Period', src='NCI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C2347804', sui='S6137818', idx='3', str='Period', src='NCI', termtype='SY', semtypeset=['resa'])
#   "exposure to"
#     start: 517
#     end: 528
#     postings:
#       PostingSTS(cui='C0332157', sui='S0642558', idx='1', str='Exposure to', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S0642558', idx='2', str='Exposure to', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S0642558', idx='3', str='Exposure to', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0332157', sui='S11885829', idx='4', str='exposure to', src='CHV', termtype='SY', semtypeset=['qlco'])
#   "chemically"
#     start: 529
#     end: 539
#     postings:
#       PostingSTS(cui='C0220806', sui='S7669275', idx='39', str='Chemically', src='NCI', termtype='AD', semtypeset=['chem'])
#   "defined"
#     start: 540
#     end: 547
#     postings:
#       PostingSTS(cui='C1704788', sui='S7670164', idx='5', str='Defined', src='NCI', termtype='AD', semtypeset=['inpr'])
#       PostingSTS(cui='C3539106', sui='S7670164', idx='7', str='Defined', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C4724435', sui='S7670164', idx='3', str='Defined', src='NCI', termtype='SY', semtypeset=['cnce'])
#   "medium"
#     start: 548
#     end: 554
#     postings:
#       PostingSTS(cui='C0009458', sui='S0943869', idx='9', str='Medium', src='NCI', termtype='SY', semtypeset=['inpr'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='1', str='Medium', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='3', str='Medium', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='4', str='Medium', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='5', str='Medium', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S11912821', idx='6', str='medium', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S6941619', idx='7', str='MEDIUM', src='NCI_CDISC', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1561547', sui='S0943869', idx='2', str='Medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1705217', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='PT', semtypeset=['sbst'])
#       PostingSTS(cui='C3244283', sui='S11912821', idx='2', str='medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C4085196', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['cnce'])
#       PostingSTS(cui='C4522282', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4522283', sui='S0943869', idx='4', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4722268', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#   "not"
#     start: 559
#     end: 562
#     postings:
#       PostingSTS(cui='C1417836', sui='S7299739', idx='7', str='NOT', src='HGNC', termtype='SYN', semtypeset=['gngm'])
#       PostingSTS(cui='C1417836', sui='S7299739', idx='8', str='NOT', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='9', str='Not', src='NCI', termtype='AD', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='10', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='11', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='12', str='Not', src='LNC', termtype='LA', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='13', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#   "sufficient"
#     start: 563
#     end: 573
#     postings:
#       PostingSTS(cui='C0205410', sui='S0324836', idx='1', str='Sufficient', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='2', str='Sufficient', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='3', str='Sufficient', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='4', str='Sufficient', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='5', str='Sufficient', src='LNC', termtype='LA', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='6', str='Sufficient', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S11942554', idx='7', str='sufficient', src='CHV', termtype='PT', semtypeset=['qlco'])
#   "effects"
#     start: 589
#     end: 596
#     postings:
#       PostingSTS(cui='C1280500', sui='S11882510', idx='7', str='effects', src='CHV', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S14453944', idx='8', str='Effects', src='NCI', termtype='SY', semtypeset=['qlco'])
#   "cells"
#     start: 612
#     end: 617
#     postings:
#       PostingSTS(cui='C0007584', sui='S0023469', idx='24', str='Cells', src='NCI_CDISC', termtype='SY', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0023469', idx='25', str='Cells', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0827167', idx='26', str='CELLS', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='1', str='Cells', src='LCH', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='2', str='Cells', src='MSH', termtype='MH', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='3', str='Cells', src='MTH', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='4', str='Cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='5', str='Cells', src='LNC', termtype='CN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='6', str='Cells', src='LCH_NW', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='7', str='Cells', src='NCI_UCUM', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='8', str='Cells', src='NCI', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='9', str='Cells', src='MTH', termtype='PN', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='10', str='cells', src='CHV', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S11865336', idx='11', str='cells', src='LNC', termtype='LPN', semtypeset=['cell'])
#   "serum"
#     start: 625
#     end: 630
#     postings:
#       PostingSTS(cui='C0229671', sui='S0403972', idx='1', str='Serum', src='SNM', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='2', str='Serum', src='SNMI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='3', str='Serum', src='LNC', termtype='LPN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='4', str='Serum', src='LNC', termtype='LS', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='5', str='Serum', src='LCH_NW', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='6', str='Serum', src='NCI', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='7', str='Serum', src='UWDA', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='8', str='Serum', src='FMA', termtype='SY', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='9', str='Serum', src='MSH', termtype='MH', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='10', str='Serum', src='SNOMEDCT_US', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='11', str='Serum', src='NCI', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0403972', idx='12', str='Serum', src='MTH', termtype='PN', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S0401563', idx='13', str='SERUM', src='NCI_CDISC', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='14', str='serum', src='AOD', termtype='DE', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='15', str='serum', src='CSP', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='16', str='serum', src='CHV', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C0229671', sui='S1239724', idx='17', str='serum', src='NCI_NCI-GLOSS', termtype='PT', semtypeset=['bdsu'])
#       PostingSTS(cui='C1546774', sui='S0403972', idx='2', str='Serum', src='HL7V2.5', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C1550100', sui='S0403972', idx='2', str='Serum', src='HL7V3.0', termtype='PT', semtypeset=['bdsu'])
#   "first"
#     start: 643
#     end: 648
#     postings:
#       PostingSTS(cui='C0205435', sui='S0324862', idx='2', str='First', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0205435', sui='S11889009', idx='3', str='first', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='6', str='First', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='7', str='First', src='SNOMEDCT_US', termtype='OAP', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='8', str='First', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='9', str='First', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1279901', sui='S0324862', idx='10', str='First', src='NCI', termtype='PT', semtypeset=['qlco'])
#   "phase"
#     start: 649
#     end: 654
#     postings:
#       PostingSTS(cui='C0205390', sui='S0324816', idx='1', str='Phase', src='SNMI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='2', str='Phase', src='SNOMEDCT_US', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='3', str='Phase', src='NCI', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S0324816', idx='4', str='Phase', src='MTH', termtype='PN', semtypeset=['tmco'])
#       PostingSTS(cui='C0205390', sui='S1237339', idx='5', str='phase', src='CHV', termtype='PT', semtypeset=['tmco'])
#       PostingSTS(cui='C1710475', sui='S1237339', idx='4', str='phase', src='NCI_CDISC-GLOSS', termtype='PT', semtypeset=['clas'])
#   "growth"
#     start: 658
#     end: 664
#     postings:
#       PostingSTS(cui='C0018270', sui='S0046170', idx='1', str='Growth', src='LCH', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='2', str='Growth', src='MSH', termtype='MH', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='4', str='Growth', src='LCH_NW', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0046170', idx='5', str='Growth', src='MTH', termtype='PN', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='6', str='growth', src='CHV', termtype='SY', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0419586', idx='7', str='growth', src='GO', termtype='PT', semtypeset=['orgf'])
#       PostingSTS(cui='C0018270', sui='S0890927', idx='8', str='GROWTH', src='OMIM', termtype='HT', semtypeset=['orgf'])
#       PostingSTS(cui='C0220844', sui='S0419586', idx='2', str='growth', src='MSH', termtype='PXQ', semtypeset=['phsf'])
#       PostingSTS(cui='C1457898', sui='S0890927', idx='2', str='GROWTH', src='MSH', termtype='QEV', semtypeset=['fndg'])
#       PostingSTS(cui='C1621966', sui='S0046170', idx='3', str='Growth', src='NCI', termtype='SY', semtypeset=['ortf'])
#       PostingSTS(cui='C2911660', sui='S0046170', idx='2', str='Growth', src='NCI', termtype='PT', semtypeset=['phpr'])
# sentence: "The cells differed in rate and duration of action potentials
# and contractions., 666"
#   "cells"
#     start: 670
#     end: 675
#     postings:
#       PostingSTS(cui='C0007584', sui='S0023469', idx='24', str='Cells', src='NCI_CDISC', termtype='SY', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0023469', idx='25', str='Cells', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007584', sui='S0827167', idx='26', str='CELLS', src='NCI_CDISC', termtype='PT', semtypeset=['lbpr'])
#       PostingSTS(cui='C0007634', sui='S0023469', idx='1', str='Cells', src='LCH', termtype='PT', semtypeset=['cell'])
# ...
#       PostingSTS(cui='C0205375', sui='S6325967', idx='5', str='uniform', src='CHV', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1608508', sui='S6325967', idx='2', str='uniform', src='HL7V3.0', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C4019284', sui='S0324800', idx='3', str='Uniform', src='MSH', termtype='PM', semtypeset=['mnob'])
#   "chemically"
#     start: 1383
#     end: 1393
#     postings:
#       PostingSTS(cui='C0220806', sui='S7669275', idx='39', str='Chemically', src='NCI', termtype='AD', semtypeset=['chem'])
#   "defined"
#     start: 1394
#     end: 1401
#     postings:
#       PostingSTS(cui='C1704788', sui='S7670164', idx='5', str='Defined', src='NCI', termtype='AD', semtypeset=['inpr'])
#       PostingSTS(cui='C3539106', sui='S7670164', idx='7', str='Defined', src='SNOMEDCT_US', termtype='PT', semtypeset=['inpr'])
#       PostingSTS(cui='C4724435', sui='S7670164', idx='3', str='Defined', src='NCI', termtype='SY', semtypeset=['cnce'])
#   "medium"
#     start: 1402
#     end: 1408
#     postings:
#       PostingSTS(cui='C0009458', sui='S0943869', idx='9', str='Medium', src='NCI', termtype='SY', semtypeset=['inpr'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='1', str='Medium', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='3', str='Medium', src='LNC', termtype='LA', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='4', str='Medium', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S0943869', idx='5', str='Medium', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S11912821', idx='6', str='medium', src='CHV', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0439536', sui='S6941619', idx='7', str='MEDIUM', src='NCI_CDISC', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C1561547', sui='S0943869', idx='2', str='Medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1705217', sui='S0943869', idx='2', str='Medium', src='NCI', termtype='PT', semtypeset=['sbst'])
#       PostingSTS(cui='C3244283', sui='S11912821', idx='2', str='medium', src='HL7V3.0', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C4085196', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['cnce'])
#       PostingSTS(cui='C4522282', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4522283', sui='S0943869', idx='4', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#       PostingSTS(cui='C4722268', sui='S0943869', idx='3', str='Medium', src='NCI', termtype='SY', semtypeset=['fndg'])
#   "not"
#     start: 1412
#     end: 1415
#     postings:
#       PostingSTS(cui='C1417836', sui='S7299739', idx='7', str='NOT', src='HGNC', termtype='SYN', semtypeset=['gngm'])
#       PostingSTS(cui='C1417836', sui='S7299739', idx='8', str='NOT', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='9', str='Not', src='NCI', termtype='AD', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='10', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='11', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='12', str='Not', src='LNC', termtype='LA', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='13', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#   "sufficient"
#     start: 1416
#     end: 1426
#     postings:
#       PostingSTS(cui='C0205410', sui='S0324836', idx='1', str='Sufficient', src='SNMI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='2', str='Sufficient', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='3', str='Sufficient', src='NCI', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='4', str='Sufficient', src='SNOMEDCT_US', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='5', str='Sufficient', src='LNC', termtype='LA', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S0324836', idx='6', str='Sufficient', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0205410', sui='S11942554', idx='7', str='sufficient', src='CHV', termtype='PT', semtypeset=['qlco'])
#   "effects"
#     start: 1444
#     end: 1451
#     postings:
#       PostingSTS(cui='C1280500', sui='S11882510', idx='7', str='effects', src='CHV', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S14453944', idx='8', str='Effects', src='NCI', termtype='SY', semtypeset=['qlco'])
#   "effects"
#     start: 1481
#     end: 1488
#     postings:
#       PostingSTS(cui='C1280500', sui='S11882510', idx='7', str='effects', src='CHV', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C1280500', sui='S14453944', idx='8', str='Effects', src='NCI', termtype='SY', semtypeset=['qlco'])
#   "not"
#     start: 1493
#     end: 1496
#     postings:
#       PostingSTS(cui='C1417836', sui='S7299739', idx='7', str='NOT', src='HGNC', termtype='SYN', semtypeset=['gngm'])
#       PostingSTS(cui='C1417836', sui='S7299739', idx='8', str='NOT', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='9', str='Not', src='NCI', termtype='AD', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='10', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='11', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='12', str='Not', src='LNC', termtype='LA', semtypeset=['ftcn'])
#       PostingSTS(cui='C1518422', sui='S6136096', idx='13', str='Not', src='NCI', termtype='SY', semtypeset=['ftcn'])
#   "result"
#     start: 1501
#     end: 1507
#     postings:
#       PostingSTS(cui='C1274040', sui='S3513919', idx='1', str='Result', src='SNOMEDCT_US', termtype='OAP', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='2', str='Result', src='SNOMEDCT_US', termtype='OAP', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='3', str='Result', src='SNOMEDCT_US', termtype='PT', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='4', str='Result', src='SNOMEDCT_US', termtype='OF', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='5', str='Result', src='SNOMEDCT_US', termtype='OF', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='6', str='Result', src='NCI', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S3513919', idx='7', str='Result', src='MTH', termtype='PN', semtypeset=['ftcn'])
#       PostingSTS(cui='C1274040', sui='S6175685', idx='8', str='result', src='NCI_BRIDG_3_0_3', termtype='PT', semtypeset=['ftcn'])
#       PostingSTS(cui='C1546471', sui='S3513919', idx='2', str='Result', src='HL7V2.5', termtype='PT', semtypeset=['idcn'])
#       PostingSTS(cui='C2825142', sui='S3513919', idx='3', str='Result', src='NCI', termtype='SY', semtypeset=['fndg'])
#   "changes"
#     start: 1511
#     end: 1518
#     postings:
#       PostingSTS(cui='C0392747', sui='S11866307', idx='13', str='changes', src='CHV', termtype='SY', semtypeset=['ftcn'])
#       PostingSTS(cui='C0443172', sui='S11866307', idx='8', str='changes', src='CHV', termtype='SY', semtypeset=['qnco'])
#   "fatty acid"
#     start: 1526
#     end: 1536
#     postings:
#       PostingSTS(cui='C0015684', sui='S0001341', idx='10', str='Fatty acid', src='SNM', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S0001341', idx='11', str='Fatty acid', src='FMA', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S0001341', idx='12', str='Fatty acid', src='SNOMEDCT_US', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S0418706', idx='13', str='fatty acid', src='CSP', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S0418706', idx='14', str='fatty acid', src='CHV', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S0418706', idx='15', str='fatty acid', src='NCI_NCI-GLOSS', termtype='PT', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S2228055', idx='18', str='FATTY ACID', src='VANDF', termtype='IN', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S6126086', idx='19', str='Fatty Acid', src='NCI_CTRP', termtype='DN', semtypeset=['orch'])
#       PostingSTS(cui='C0015684', sui='S6126086', idx='20', str='Fatty Acid', src='NCI', termtype='PT', semtypeset=['orch'])
#   "composition"
#     start: 1537
#     end: 1548
#     postings:
#       PostingSTS(cui='C0486616', sui='S1937865', idx='1', str='Composition', src='NCI', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='2', str='Composition', src='LNC', termtype='LPN', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='3', str='Composition', src='LCH', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='4', str='Composition', src='LNC', termtype='CN', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='5', str='Composition', src='NCI_CDISC', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='6', str='Composition', src='NCI_CDISC', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='7', str='Composition', src='SNOMEDCT_US', termtype='SY', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S1937865', idx='8', str='Composition', src='MTH', termtype='PN', semtypeset=['qlco'])
#       PostingSTS(cui='C0486616', sui='S6325206', idx='9', str='composition', src='CHV', termtype='PT', semtypeset=['qlco'])
#       PostingSTS(cui='C1555710', sui='S6325206', idx='2', str='composition', src='HL7V3.0', termtype='PT', semtypeset=['idcn'])
#   "whole"
#     start: 1556
#     end: 1561
#     postings:
#       PostingSTS(cui='C0444667', sui='S1063448', idx='1', str='Whole', src='NCI_CDISC', termtype='SY', semtypeset=['qnco'])
#       PostingSTS(cui='C0444667', sui='S1063448', idx='2', str='Whole', src='SNOMEDCT_US', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0444667', sui='S1063448', idx='3', str='Whole', src='NCI', termtype='PT', semtypeset=['qnco'])
#       PostingSTS(cui='C0444667', sui='S1063448', idx='4', str='Whole', src='MTH', termtype='PN', semtypeset=['qnco'])
#       PostingSTS(cui='C0444667', sui='S11952962', idx='5', str='whole', src='CHV', termtype='PT', semtypeset=['qnco'])
#   "cell"
#     start: 1562
#     end: 1566
#     postings:
#       PostingSTS(cui='C0007634', sui='S0002474', idx='12', str='Cell', src='MSH', termtype='PM', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='13', str='Cell', src='SNM', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='14', str='Cell', src='FMA', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='15', str='Cell', src='NCI', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='16', str='Cell', src='UWDA', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='17', str='Cell', src='NCI', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0002474', idx='18', str='Cell', src='SNOMEDCT_US', termtype='SY', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0416322', idx='22', str='cell', src='CSP', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0416322', idx='23', str='cell', src='GO', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0416322', idx='24', str='cell', src='CHV', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C0007634', sui='S0416322', idx='25', str='cell', src='NCI_NCI-GLOSS', termtype='PT', semtypeset=['cell'])
#       PostingSTS(cui='C1136359', sui='S0002474', idx='9', str='Cell', src='NCI', termtype='SY', semtypeset=['mnob'])
#       PostingSTS(cui='C1269647', sui='S0002474', idx='3', str='Cell', src='SNOMEDCT_US', termtype='IS', semtypeset=['cell'])
#       PostingSTS(cui='C1413336', sui='S7484925', idx='3', str='CELL', src='OMIM', termtype='ACR', semtypeset=['gngm'])
#       PostingSTS(cui='C1704653', sui='S0002474', idx='3', str='Cell', src='NCI_FDA', termtype='PT', semtypeset=['medd'])
#       PostingSTS(cui='C1704653', sui='S0002474', idx='4', str='Cell', src='NCI', termtype='SY', semtypeset=['medd'])
#       PostingSTS(cui='C1948049', sui='S0002474', idx='2', str='Cell', src='NCI', termtype='PT', semtypeset=['spco'])
#   "phospholipids"
#     start: 1567
#     end: 1580
#     postings:
#       PostingSTS(cui='C0031676', sui='S1436372', idx='1', str='phospholipids', src='AOD', termtype='DE', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S1436372', idx='2', str='phospholipids', src='CHV', termtype='SY', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S1436372', idx='3', str='phospholipids', src='MTH', termtype='PN', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='4', str='Phospholipids', src='LCH', termtype='PT', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='5', str='Phospholipids', src='MSH', termtype='MH', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='6', str='Phospholipids', src='NCI', termtype='SY', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='7', str='Phospholipids', src='LCH_NW', termtype='PT', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='8', str='Phospholipids', src='DRUGBANK', termtype='SY', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='9', str='Phospholipids', src='SNOMEDCT_US', termtype='OP', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S0073338', idx='10', str='Phospholipids', src='RXNORM', termtype='IN', semtypeset=['bacs', 'orch'])
#       PostingSTS(cui='C0031676', sui='S2240514', idx='11', str='PHOSPHOLIPIDS', src='VANDF', termtype='IN', semtypeset=['bacs', 'orch'])
#   "mitochondrial membrane"
#     start: 1588
#     end: 1610
#     postings:
#       PostingSTS(cui='C0596952', sui='S1234365', idx='3', str='mitochondrial membrane', src='CSP', termtype='PT', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S1234365', idx='4', str='mitochondrial membrane', src='GO', termtype='PT', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S3011716', idx='5', str='Mitochondrial membrane', src='FMA', termtype='SY', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S3011716', idx='6', str='Mitochondrial membrane', src='UWDA', termtype='SY', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S3011716', idx='7', str='Mitochondrial membrane', src='SNOMEDCT_US', termtype='PT', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S6133573', idx='8', str='Mitochondrial Membrane', src='MSH', termtype='PM', semtypeset=['celc'])
#       PostingSTS(cui='C0596952', sui='S6133573', idx='9', str='Mitochondrial Membrane', src='NCI', termtype='PT', semtypeset=['celc'])
#   "nitroblue tetrazolium"
#     start: 1639
#     end: 1660
#     postings:
#       PostingSTS(cui='C0028147', sui='S0066863', idx='1', str='Nitroblue Tetrazolium', src='MSH', termtype='MH', semtypeset=['irda', 'orch'])
#       PostingSTS(cui='C0028147', sui='S1235878', idx='2', str='nitroblue tetrazolium', src='CHV', termtype='PT', semtypeset=['irda', 'orch'])

# %%
inputtext[1639:1660]
# Out:
# 'nitroblue tetrazolium'

# %%
inputtext[821:831]
# Out:
# 'deficiency'
